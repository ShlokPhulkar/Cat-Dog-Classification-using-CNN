# %% [markdown]
# # Dog cat image classification

# %%
#Load the libraries
import keras
import keras.utils as ku
from sklearn import metrics
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPool2D,Flatten

# %%
#Load the dataset
Train_data=ku.image_dataset_from_directory(directory="training_set/",image_size=(256, 256))
Test_data=ku.image_dataset_from_directory(directory="test_set/",image_size=(256,256))
# Out:
# Found 8005 files belonging to 2 classes.
# Found 2023 files belonging to 2 classes.

# %%
#Prediction
#Input image
test_image =keras.utils.load_img("cat.4001.jpg",target_size=(256,256))
#For show image
test_image = keras.utils.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
# Result array
result = classifier.predict(test_image)
#Mapping result array with the main name list
i=0
if(result>=0.5):
      print("Dog")
else:
      print("Cat")
# Out:
# 1/1 [==============================] - 0s 248ms/step
# Cat

# %%
#Prediction
#Input image
test_image =keras.utils.load_img("dog.4001.jpg",target_size=(256,256))
#For show image
test_image = keras.utils.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
# Result array
result = classifier.predict(test_image)
#Mapping result array with the main name list
i=0
if(result>=0.5):
      print("Dog")
else:
      print("Cat")
# Out:
# 1/1 [==============================] - 0s 43ms/step
# Dog

# %%
#Verification
test_image1 =keras.utils.load_img("cat.4001.jpg",target_size=(256,256))
test_image1
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x232351AA160>

# %%
#Verfification
test_image2 =keras.utils.load_img("dog.4001.jpg",target_size=(256,256))
test_image2
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x2323C318DF0>

# %% [markdown]
# # Thank You
